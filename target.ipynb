# %% [markdown]
# # Target model training

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from target import MNISTConvTarget

# %% [markdown]
# ## MNIST
#
# ### Data loading and preprocessing
#
# Load the MNIST training and test set images:

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
print(f'training set: {train_images.shape}, {train_labels.shape}')
print(f'test set: {test_images.shape}, {test_labels.shape}')
# Out:
# training set: (60000, 28, 28), (60000,)
# test set: (10000, 28, 28), (10000,)

# %% [markdown]
# Reshape the images to `28 x 28 x 1` and normalize them to `[-1, 1]`:

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')
test_images = (test_images - 127.5) / 127.5
test_images.shape
# Out:
# (10000, 28, 28, 1)

# %% [markdown]
# Convert the label integers to binary class matrices (one-hot encoding):

# %%
train_labels = tf.keras.utils.to_categorical(train_labels, num_classes=10)
train_labels.shape
# Out:
# (60000, 10)

# %%
test_labels = tf.keras.utils.to_categorical(test_labels, num_classes=10)
test_labels.shape
# Out:
# (10000, 10)

# %% [markdown]
# ### MNISTConvTarget
#
# `MNISTConvTarget` is a CNN-based MNIST classifier:

# %%
target = MNISTConvTarget()
tf.keras.utils.plot_model(target.model, show_shapes=True, show_layer_names=False)

# %%
target.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %% [markdown]
# #### Training

# %%
history = target.fit(
    train_images, train_labels,
    epochs=6,
    batch_size=128,
    validation_split=.1)
# Out:
# Epoch 1/6
#  - ETA: 9s - loss: 0.6675 - categorical_accuracy: 0.7829
# Epoch 2/6
# 422/422 [==============================] - 41s 96ms/step - loss: 0.0722 - categorical_accuracy: 0.9782 - val_loss: 0.0469 - val_categorical_accuracy: 0.9872
# Epoch 3/6
# 422/422 [==============================] - 40s 95ms/step - loss: 0.0479 - categorical_accuracy: 0.9853 - val_loss: 0.0331 - val_categorical_accuracy: 0.9908
# Epoch 4/6
# 422/422 [==============================] - 41s 97ms/step - loss: 0.0352 - categorical_accuracy: 0.9898 - val_loss: 0.0293 - val_categorical_accuracy: 0.9913
# Epoch 5/6
# 422/422 [==============================] - 41s 97ms/step - loss: 0.0326 - categorical_accuracy: 0.9901 - val_loss: 0.0332 - val_categorical_accuracy: 0.9912
# Epoch 6/6
# 422/422 [==============================] - 40s 95ms/step - loss: 0.0244 - categorical_accuracy: 0.9920 - val_loss: 0.0323 - val_categorical_accuracy: 0.9907

# %%
import time

weights_path = (f'training/mnist_conv_target_'
                f'{time.strftime("%Y%m%d%H%M%S")}.h5')

target.save_weights(weights_path)

# %% [markdown]
# Plot the loss and accuracy on the training and validation sets over training epochs:

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])

plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='best')

plt.show()

# %% [markdown]
# #### Test set performance
#
# Check the model's loss and accuracy on the test set:

# %%
loss, accuracy = target.evaluate(test_images, test_labels, verbose=False)
print(f'test loss: {loss:.3}')
print(f'test accuracy: {accuracy:.3}')
# Out:
# test loss: 0.0241
# test accuracy: 0.993

# %% [markdown]
# Plot the confusion matrix:

# %%
test_labels_pred = target.predict(test_images)

cm = tf.math.confusion_matrix(
    labels=test_labels.argmax(axis=1),
    predictions=test_labels_pred.argmax(axis=1)).numpy()

# %%
cm_norm = np.around(cm / cm.sum(axis=1), decimals=2)

classes = list(range(10))
cm_df = pd.DataFrame(cm_norm, index=classes, columns=classes)

# %%
fig = plt.figure(figsize=(8, 8))
sns.heatmap(cm_df, annot=True)

plt.tight_layout()
plt.ylabel('true label')
plt.xlabel('predicted label')
plt.show()
